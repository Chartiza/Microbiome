# %% [markdown]
# ## Script is designed to create nice looking taxonomy table from last GTDB release
#
# Input files were taken from last to day release of GTDB DB (release207/207.0) <br>
# https://data.ace.uq.edu.au/public/gtdb/data/releases/release207/207.0/
#
# Output is: <br>
# Plots with taxonomy visualisation

# %%
# import packages
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import os
import glob

# %%
colnames = ['dom','phylum','class','order','family','genus','sp']

bac = pd.read_csv('input/bac120_taxonomy_r207.tsv', sep=';', names=colnames, header=None)
arh = pd.read_csv('input/ar53_taxonomy_r207.tsv', sep=';', names=colnames, header=None)

bac.head(2)
# Out:
#                                dom             phylum                   class  \
# 0  RS_GCF_000566285.1\td__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 1  RS_GCF_003460375.1\td__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
#
#                  order                 family           genus  \
# 0  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
# 1  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
#
#                     sp
# 0  s__Escherichia coli
# 1  s__Escherichia coli

# %%
# modify bac120 table

bac['domain'] = bac['dom'].str.split('__', expand=True)[1]
bac['phylum'] = bac['phylum'].str.replace(r'p__', '')
bac['class'] = bac['class'].str.replace(r'c__', '')
bac['order'] = bac['order'].str.replace(r'o__', '')
bac['family'] = bac['family'].str.replace(r'f__', '')
bac['genus'] = bac['genus'].str.replace(r'g__', '')
bac['sp'] = bac['sp'].str.replace(r's__', '')
bac = bac[['domain','phylum','class','order','family','genus','sp']]
bac = bac.drop_duplicates()

bac.head(2)
# Out:
#          domain          phylum                class             order  \
# 0      Bacteria  Proteobacteria  Gammaproteobacteria  Enterobacterales
# 26859  Bacteria      Firmicutes              Bacilli  Staphylococcales
#
#                    family           genus                     sp
# 0      Enterobacteriaceae     Escherichia       Escherichia coli
# 26859   Staphylococcaceae  Staphylococcus  Staphylococcus aureus

# %%
# modify arch table

arh['domain'] = arh['dom'].str.split('__', expand=True)[1]
arh['phylum'] = arh['phylum'].str.replace(r'p__', '')
arh['class'] = arh['class'].str.replace(r'c__', '')
arh['order'] = arh['order'].str.replace(r'o__', '')
arh['family'] = arh['family'].str.replace(r'f__', '')
arh['genus'] = arh['genus'].str.replace(r'g__', '')
arh['sp'] = arh['sp'].str.replace(r's__', '')
arh = arh[['domain','phylum','class','order','family','genus','sp']]
arh = arh.drop_duplicates()

arh.head(2)
# Out:
#      domain          phylum            class              order  \
# 0   Archaea  Halobacteriota  Methanosarcinia  Methanosarcinales
# 73  Archaea  Thermoproteota    Thermoproteia       Sulfolobales
#
#                 family           genus                         sp
# 0   Methanosarcinaceae  Methanosarcina       Methanosarcina mazei
# 73       Sulfolobaceae      Sulfolobus  Sulfolobus acidocaldarius

# %%
frames = [bac,arh]
gtdb = pd.concat(frames)

gtdb.head(2)
# Out:
#          domain          phylum                class             order  \
# 0      Bacteria  Proteobacteria  Gammaproteobacteria  Enterobacterales
# 26859  Bacteria      Firmicutes              Bacilli  Staphylococcales
#
#                    family           genus                     sp
# 0      Enterobacteriaceae     Escherichia       Escherichia coli
# 26859   Staphylococcaceae  Staphylococcus  Staphylococcus aureus

# %% [markdown]
# ### Draw plots

# %%
gtdb['count'] = 1

fig = px.sunburst(gtdb,
                  path=['domain','phylum','class'],
                  values='count',
                  title="GTDB, release207/207.0",
                  width=750, height=750)

fig.write_html("results/GTDB_all_class.html")
fig.show()
# Out:
# <div>                            <div id="1b5086fc-6a54-481c-85d5-442c51ffbdeb" class="plotly-graph-div" style="height:750px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b5086fc-6a54-481c-85d5-442c51ffbdeb")) {                    Plotly.newPlot(                        "1b5086fc-6a54-481c-85d5-442c51ffbdeb",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Bacteria/Bacteroidota/0-14-0-80-59-12","Bacteria/Nitrospinota_B/2-12-FULL-45-22","Bacteria/Lindowbacteria/2-12-FULL-62-27","Bacteria/WOR-3/32-111","Bacteria/Latescibacterota/4484-107","Bacteria/4484-113/4484-113","Bacteria/Patescibacteria/4484-211","Bacteria/Omnitrophota/4484-213","Bacteria/4572-55/4572-55","Bacteria/Nitrospirota/9FT-COMBO-42-15","Bacteria/AABM5-125-24/AABM5-125-24","Bacteria/Marinisomatota/AB16","Bacteria/Patescibacteria/ABY1","Bacteria/Edwardsbacteria/AC1","Bacteria/ARS69/ARS69","Bacteria/Armatimonadota/Abditibacteria","Bacteria/Actinobacteriota/Acidimicrobiia","Bacteria/Acidobacteriota/Acidobacteriae","Bacteria/Actinobacteriota/Actinomycetia","Archaea/Aenigmatarchaeota/Aenigmatarchaeia","Bacteria/Aerophobota/Aerophobia","Bacteria/Proteobacteria/Alphaproteobacteria","Archaea/Altiarchaeota/Altiarchaeia","Bacteria/Acidobacteriota/Aminicenantia","Bacteria/Desulfobacterota_C/Anaeroferrophillalia","Bacteria/Chloroflexota/Anaerolineae","Bacteria/Patescibacteria/Andersenbacteria","Bacteria/Actinobacteriota/Aquicultoria","Bacteria/Aquificota/Aquificae","Archaea/Halobacteriota/Archaeoglobi","Bacteria/Armatimonadota/Armatimonadia","Bacteria/Atribacterota/Atribacteria","Bacteria/Planctomycetota/B129-G9","Bacteria/B130-G9/B130-G9","Bacteria/Planctomycetota/B143-G9","Bacteria/Planctomycetota/B15-G4","Archaea/B1Sed10-29/B1Sed10-29","Bacteria/RBG-13-66-14/B26-G2","Bacteria/Acidobacteriota/B3-B38","Bacteria/AABM5-125-24/B3-LCP","Archaea/Thermoplasmatota/B47-G6","Bacteria/Spirochaetota/B62-G9","Bacteria/Myxococcota/B64-G9","Archaea/Hadarchaeota/B88-G9","Bacteria/BMS3Abin14/BMS3Abin14","Bacteria/AABM5-125-24/BMS3BBIN04","Bacteria/Marinisomatota/BS150m-G59","Bacteria/BS750m-G25/BS750m-G25","Bacteria/BS750m-G34/BS750m-G34","Bacteria/Desulfobacterota/BSN033","Bacteria/Dependentiae/Babeliae","Bacteria/Firmicutes/Bacilli","Bacteria/Bdellovibrionota/Bacteriovoracia","Bacteria/Bacteroidota/Bacteroidia","Archaea/Asgardarchaeota/Baldrarchaeia","Archaea/Thermoproteota/Bathyarchaeia","Bacteria/Bdellovibrionota/Bdellovibrionia","Bacteria/Bdellovibrionota/Bdellovibrionia_A","Bacteria/Desulfobacterota_B/Binatia","Bacteria/Bipolaricaulota/Bipolaricaulia","Bacteria/Acidobacteriota/Blastocatellia","Archaea/Halobacteriota/Bog-38","Bacteria/Spirochaetota/Brachyspirae","Bacteria/Myxococcota/Bradymonadia","Bacteria/Spirochaetota/Brevinematia","Bacteria/Planctomycetota/Brocadiae","Bacteria/Firmicutes/Bu12","Bacteria/CAIJMQ01/CAIJMQ01","Bacteria/Acidobacteriota/CAIWXX01","Bacteria/Armatimonadota/CAIYQO01","Bacteria/CG03/CG03","Bacteria/UBA9089/CG2-30-40-21","Bacteria/CG2-30-53-67/CG2-30-53-67","Bacteria/Patescibacteria/CG2-30-54-11","Bacteria/CG2-30-70-394/CG2-30-70-394","Bacteria/CLD3/CLD3","Bacteria/Patescibacteria/CPR2","Bacteria/Patescibacteria/CPR2_A","Bacteria/Patescibacteria/CPR3","Bacteria/CSP1-3/CSP1-3","Bacteria/CSSED10-310/CSSED10-310","Bacteria/Caldisericota/Caldisericia","Bacteria/Calditrichota/Calditrichia","Bacteria/Calescibacterota/Calescibacteriia","Bacteria/Campylobacterota/Campylobacteria","Bacteria/Firmicutes_A/Ch29","Bacteria/Fibrobacterota/Chitinivibrionia","Bacteria/Chlamydiota/Chlamydiia","Bacteria/Bacteroidota/Chlorobia","Bacteria/Chloroflexota/Chloroflexia","Bacteria/Chrysiogenota/Chrysiogenetes","Bacteria/Armatimonadota/Chthonomonade ...

# %%
bac['count'] = 1

fig = px.sunburst(bac,
                  path=['domain','phylum','class','order','family','genus'],
                  values='count',
                  title="GTDB, release207/207.0",
                  width=750, height=750)

fig.write_html("results/GTDB_bac120.html")

# %%
arh['count'] = 1

fig = px.sunburst(arh,
                  path=['domain','phylum','class','order','family','genus'],
                  values='count',
                  title="GTDB, release207/207.0",
                  width=750, height=750)

fig.write_html("results/GTDB_arch.html")
